# %%
def print_board(board):
    for row in board:
        print(" | ".join(row))
        print("-" * 5)

def check_winner(board):
    # Sprawdź wiersze
    for row in board:
        if row[0] == row[1] == row[2] != ' ':
            return True
    
    # Sprawdź kolumny
    for col in range(3):
        if board[0][col] == board[1][col] == board[2][col] != ' ':
            return True
    
    # Sprawdź przekątne
    if board[0][0] == board[1][1] == board[2][2] != ' ' or \
       board[0][2] == board[1][1] == board[2][0] != ' ':
        return True
    
    return False

def tic_tac_toe():
    board = [[' ' for _ in range(3)] for _ in range(3)]
    player = 'X'

    print("Witaj w grze Kółko i krzyżyk!")
    print_board(board)

    while True:
        row = int(input("Wybierz numer wiersza (1-3): ")) - 1
        col = int(input("Wybierz numer kolumny (1-3): ")) - 1

        if board[row][col] == ' ':
            board[row][col] = player
            print_board(board)

            if check_winner(board):
                print(f"Gratulacje! Gracz {player} wygrywa!")
                break
            elif all(board[i][j] != ' ' for i in range(3) for j in range(3)):
                print("Remis!")
                break

            player = 'O' if player == 'X' else 'X'
        else:
            print("To pole jest już zajęte. Spróbuj ponownie.")

if __name__ == "__main__":
    tic_tac_toe()
# Out:
# Witaj w grze Kółko i krzyżyk!
#   |   |
# -----
#   |   |
# -----
#   |   |
# -----
# Wybierz numer wiersza (1-3): 1
# Wybierz numer kolumny (1-3): 2
#   | X |
# -----
#   |   |
# -----
#   |   |
# -----
# Wybierz numer wiersza (1-3): 2
# Wybierz numer kolumny (1-3): 1
#   | X |
# -----
# O |   |
# -----
#   |   |
# -----
# Wybierz numer wiersza (1-3): 2
# Wybierz numer kolumny (1-3): 3
#   | X |
# -----
# O |   | X
# -----
#   |   |
# -----
# Wybierz numer wiersza (1-3): 3
# Wybierz numer kolumny (1-3): 3
#   | X |
# -----
# O |   | X
# -----
#   |   | O
# -----
# Wybierz numer wiersza (1-3): 1
# Wybierz numer kolumny (1-3): 1
# X | X |
# -----
# O |   | X
# -----
#   |   | O
# -----
# Wybierz numer wiersza (1-3): 1
# Wybierz numer kolumny (1-3): 3
# X | X | O
# -----
# O |   | X
# -----
#   |   | O
# -----
# Wybierz numer wiersza (1-3): 1
# Wybierz numer kolumny (1-3): 3
# To pole jest już zajęte. Spróbuj ponownie.
# Wybierz numer wiersza (1-3): 1
# Wybierz numer kolumny (1-3): 2
# To pole jest już zajęte. Spróbuj ponownie.
# Wybierz numer wiersza (1-3): 2
# Wybierz numer kolumny (1-3): 2
# X | X | O
# -----
# O | X | X
# -----
#   |   | O
# -----
# Wybierz numer wiersza (1-3): 3
# Wybierz numer kolumny (1-3): 1
# X | X | O
# -----
# O | X | X
# -----
# O |   | O
# -----
# Wybierz numer wiersza (1-3): 3
# Wybierz numer kolumny (1-3): 2
# X | X | O
# -----
# O | X | X
# -----
# O | X | O
# -----
# Gratulacje! Gracz X wygrywa!
